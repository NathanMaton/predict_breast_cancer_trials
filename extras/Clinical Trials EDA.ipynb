# %%
import pandas as pd
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Drugs table

# %%
drugs = pd.read_excel('bcdrugs.xlsx')
drugs.shape
# Out:
# (1203, 36)

# %% [markdown]
# Drugs columns = 'Drug ID', 'Drug Name', 'CAS Number', 'Chemical Name',
#        'New Molecular Entity', 'Drug Interactions', 'Comparative Efficacy',
#        'Highest Development Phase', 'Indication', 'Molecular Formula',
#        'Mechanism Of Action', 'Organisation',
#        'Pharmacodynamic Characteristics', 'Route Of Administration',
#        'Route Of Elimination', 'Pharmacokinetic Characteristics',
#        'Adverse Events', 'Therapeutic Class (EphMRA)',
#        'Therapeutic Class (WHO)', 'Synonyms/Brand Names',
#        'Antimicrobial Activity', 'Immunogenicity',
#        'Last Significant Update Date', 'Therapeutic Area',
#        'Orphan Designation', 'License Availability', 'Brands', 'On Fastrack',
#        'Fastrack country', 'On PRIME', 'PRIME country', 'Biomarkers-Inclusion',
#        'Biomarkers-Exclusion', 'Biomarkers-Outcome Measure',
#        'Biomarkers-Safety', 'Biomarkers-not specified'

# %%
drugs['Highest Development Phase'].value_counts()
# Out:
# Marketed                                     175
# Preclinical                                  167
# Phase II                                     149
# No development reported (Preclinical)         87
# Phase III                                     84
# Discontinued (II)                             84
# Phase I                                       65
# Discontinued (Preclinical)                    60
# Discontinued (III)                            46
# Phase I/II                                    44
# Research                                      35
# Discontinued (I)                              25
# No development reported (I)                   21
# No development reported (Research)            21
# No development reported (II)                  20
# Registered                                    15
# Phase II/III                                  14
# Discontinued (I/II)                           11
# Preregistration                               10
# No development reported (Clinical)            10
# Discontinued (Preregistration)                10
# No development reported (I/II)                 7
# Clinical Phase Unknown                         7
# Suspended (I)                                  5
# Suspended (II)                                 5
# Discontinued (Clinical)                        4
# No development reported (III)                  3
# Suspended (III)                                3
# No development reported                        2
# Discontinued (Registered)                      2
# Discontinued (II/III)                          2
# No development reported (Preregistration)      2
# Phase Unknown                                  2
# Preregistration Submission Withdrawal          1
# Discontinued                                   1
# No development reported (Registered)           1
# Market Withdrawal                              1
# Discontinued (Research)                        1
# Phase 0                                        1
# Name: Highest Development Phase, dtype: int64

# %% [markdown]
# ## Trials table

# %%
trials = pd.read_excel('bcdrugsct.xlsx')
trials.shape
# Out:
# (4529, 41)

# %%
cols = ['Trial ID','Mechanism of action', 'Drug class (therapeutic effect)', 'Drug class (chemical)', \
        'Indication', 'Organisations', 'Trial Design', 'Location', 'Phase of Trial', 'Subject Age',\
        'Planned Subject Number', 'Trial Centre Details', 'Lead Centre', 'Trial Initiation date', \
        'Trial End date', 'Trial Status', 'Trial History', 'Diseases treated', 'Primary Drugs']
smaller_trials = trials[cols]
date_cols = ['Phase of Trial','Trial Initiation date', 'Trial End date', 'trial_start','trial_end']

# %%
def phase_1(drug_name):
    '''
    take earliest Phase I date and latest Phase II
    '''
    tucatinib_trials = trials[trials['Primary Drugs']==drug_name]
    trial_phases = ['Phase I', 'Phase II', 'Phase III']
    cleaned_tucatinib_trials = tucatinib_trials[tucatinib_trials['Phase of Trial'].isin(trial_phases)]
    phase_dummies = pd.get_dummies(cleaned_tucatinib_trials['Phase of Trial'])
    cleaned_tucatinib_trials_dummies = cleaned_tucatinib_trials.join(phase_dummies)
    #cleaned_tucatinib_trials_dummies[['Trial Initiation date', 'Trial End date']]
    df = cleaned_tucatinib_trials.join(phase_dummies)

    #not DRY as the answers to make multiargument apply functions involved more complicated things than I wanted.
    def start_to_datetime(x):
        date_str = re.findall('[\d\s\w]*', x['Trial Initiation date'])[0].strip()
        if date_str == '':
            return False
        else:
            return pd.to_datetime(date_str)

    def end_to_datetime(x):
        date_str = re.findall('[\d\s\w]*', x['Trial End date'])[0].strip()
        if date_str == '':
            return False
        else:
            return pd.to_datetime(date_str)

    df['trial_start'] = df.apply(start_to_datetime, axis=1)
    df['trial_end'] = df.apply(end_to_datetime, axis=1)

    t_phase_1_min = min(list(df[(df['trial_start']!=False) & (df['Phase of Trial']=='Phase I')]['trial_start'].values))
    t_phase_1_max = max(list(df[(df['trial_start']!=False) & (df['Phase of Trial']=='Phase I')]['trial_start'].values))

    return f'min is {t_phase_1_min} and max is {t_phase_1_max}'

phase_1('Xentuzumab')


# df['split_start_date'] = df['Trial Initiation date'].apply(lambda x: x.split(' '))
# df['split_end_date'] = df['Trial End date'].apply(lambda x: x.split(' '))
# df2 = df[df['split_start_date'].apply(lambda x: len(x[:3]))==3]
# df3 = df2[df2['split_end_date'].apply(lambda x: len(x[:3]))==3]
# df3[date_cols]
#df3.apply(lambda x: ' '.join(x['split_start_date']))
# in_progress_trials = trials[trials['split_start_date'].apply(lambda x: len(x[:3]))==3]
# planned_trials = trials[trials['split_start_date'].apply(lambda x: len(x[:3]))==2]
# # one_split = trials['split_end_date'].values[0]
# # pd.to_datetime(' '.join(one_split[:3]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _ensure_valid_index(self, value)
#    3172             try:
# -> 3173                 value = Series(value)
#    3174             except:
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     276
# --> 277                 data = SingleBlockManager(data, index, fastpath=True)
#     278
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/internals.py in __init__(self, block, axis, do_integrity_check, fastpath)
#    4676         if not isinstance(block, Block):
# -> 4677             block = make_block(block, placement=slice(0, len(axis)), ndim=1)
#    4678
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/internals.py in make_block(values, placement, klass, ndim, dtype, fastpath)
#    3204
# -> 3205     return klass(values, ndim=ndim, placement=placement)
#    3206
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/internals.py in __init__(self, values, placement, ndim)
#    2302         super(ObjectBlock, self).__init__(values, ndim=ndim,
# -> 2303                                           placement=placement)
#    2304
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/internals.py in __init__(self, values, placement, ndim)
#     124                 'Wrong number of items passed {val}, placement implies '
# --> 125                 '{mgr}'.format(val=len(self.values), mgr=len(self.mgr_locs)))
#     126
#
# ValueError: Wrong number of items passed 41, placement implies 0
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-36b230eeff8b> in <module>
#      35     return f'min is {t_phase_1_min} and max is {t_phase_1_max}'
#      36
# ---> 37 phase_1('Xentuzumab')
#      38
#      39
#
# <ipython-input-7-36b230eeff8b> in phase_1(drug_name)
#      27             return pd.to_datetime(date_str)
#      28
# ---> 29     df['trial_start'] = df.apply(start_to_datetime, axis=1)
#      30     df['trial_end'] = df.apply(end_to_datetime, axis=1)
#      31
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3117         else:
#    3118             # set column
# -> 3119             self._set_item(key, value)
#    3120
#    3121     def _setitem_slice(self, key, value):
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3191         """
#    3192
# -> 3193         self._ensure_valid_index(value)
#    3194         value = self._sanitize_column(key, value)
#    3195         NDFrame._set_item(self, key, value)
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _ensure_valid_index(self, value)
#    3173                 value = Series(value)
#    3174             except:
# -> 3175                 raise ValueError('Cannot set a frame with no defined index '
#    3176                                  'and a value that cannot be converted to a '
#    3177                                  'Series')
#
# ValueError: Cannot set a frame with no defined index and a value that cannot be converted to a Series

# %%
phase_two = smaller_trials[smaller_trials['Phase of Trial'] == 'Phase II']
phase_three = smaller_trials[smaller_trials['Phase of Trial'] == 'Phase III']

# %%
unique_drugs =list(smaller_trials['Primary Drugs'].unique())

# %%
trials[trials['Primary Drugs']=='Tucatinib']
# Out:
#        Trial ID                                        Trial Title  \
# 1     700240183  A Phase 1b, Open-label Study to Assess the Saf...
# 10    700257487  Phase 2 Randomized, Double-Blinded, Controlled...
# 16    700304216  A Phase 1, Open-Label, Fixed-Sequence, Drug-Dr...
# 478   700302859  A Phase 1, Randomized, Partially Double-Blind,...
# 481   700238859  A Phase 1b, Open-label Study to Assess the Saf...
# 489   700301177  An Open-label, Non-randomized, Single-dose, Pa...
# 570   700301239  A Phase 1, Open-Label, Fixed-sequence, 5-part,...
# 915   700302217  A Phase 1, Open-label Study of the Absorption,...
# 1507  700026682  A Study of ARRY-380 in Patients With Advanced ...
# 1760  700292929  Expanded Access Use of Tucatinib for HER2+ Met...
# 1812  700264999  Phase 3 study of tucatinib (ONT-380) in combin...
# 1814  700265020  A phase 2 study of tucatinib (ONT-380) in comb...
# 3880  700235510  Proof-of-concept trial of ARRY-380 in patients...
#
#                                     Mechanism of action  \
# 1     Antibody-dependent cell cytotoxicity, Antimeta...
# 10    Antibody-dependent cell cytotoxicity, Antibody...
# 16    AMP activated protein kinase stimulants, Emiss...
# 478   DNA gyrase inhibitors, ERBB 2 receptor antagon...
# 481   Apoptosis stimulants, ERBB 2 receptor antagoni...
# 489                         ERBB 2 receptor antagonists
# 570   14-alpha demethylase inhibitors, Angiogenesis ...
# 915                         ERBB 2 receptor antagonists
# 1507                        ERBB 2 receptor antagonists
# 1760                        ERBB 2 receptor antagonists
# 1812  Apoptosis stimulants, ERBB 2 receptor antagoni...
# 1814  Apoptosis stimulants, ERBB 2 receptor antagoni...
# 3880                        ERBB 2 receptor antagonists
#
#                         Drug class (therapeutic effect)  \
# 1     Antineoplastics, Antineoplastics, Antineoplastics
# 10    Antineoplastics, Antineoplastics, Antineoplast...
# 16                 Antineoplastics, Antihyperglycaemics
# 478                     Antineoplastics, Antibacterials
# 481                    Antineoplastics, Antineoplastics
# 489                                     Antineoplastics
# 570   Antineoplastics, Antihyperlipidaemics, Antifun...
# 915                                     Antineoplastics
# 1507                                    Antineoplastics
# 1760                                    Antineoplastics
# 1812                   Antineoplastics, Antineoplastics
# 1814                   Antineoplastics, Antineoplastics
# 3880                                    Antineoplastics
#
#                                   Drug class (chemical)  \
# 1     2 ring heterocyclic compounds, Diamines, Furan...
# 10    2 ring heterocyclic compounds, Diamines, Furan...
# 16    2 ring heterocyclic compounds, Diamines, Furan...
# 478   2 ring heterocyclic compounds, Diamines, Furan...
# 481   2 ring heterocyclic compounds, Diamines, Furan...
# 489   2 ring heterocyclic compounds, Diamines, Furan...
# 570   2 ring heterocyclic compounds, Diamines, Furan...
# 915   2 ring heterocyclic compounds, Diamines, Furan...
# 1507  2 ring heterocyclic compounds, Diamines, Furan...
# 1760  2 ring heterocyclic compounds, Diamines, Furan...
# 1812  Drug conjugates, Macrolides, Maytansinoids, 2 ...
# 1814  Drug conjugates, Macrolides, Maytansinoids, 2 ...
# 3880  2 ring heterocyclic compounds, Diamines, Furan...
#
#                                 Drug class (biological)  \
# 1                                 Monoclonal antibodies
# 10         Monoclonal antibodies, Monoclonal antibodies
# 16                                                  NaN
# 478                                                 NaN
# 481   Immunoconjugates, Immunotoxins, Monoclonal ant...
# 489                                                 NaN
# 570                                                 NaN
# 915                                                 NaN
# 1507                                                NaN
# 1760                                                NaN
# 1812  Immunoconjugates, Immunotoxins, Monoclonal ant...
# 1814  Immunoconjugates, Immunotoxins, Monoclonal ant...
# 3880                                                NaN
#
#                                              Indication  \
# 1            Advanced breast cancer, Male breast cancer
# 10    Advanced breast cancer, Carcinoma, Male breast...
# 16                     Breast cancer, Colorectal cancer
# 478                    Breast cancer, Colorectal cancer
# 481          Advanced breast cancer, Male breast cancer
# 489                    Breast cancer, Colorectal cancer
# 570                    Breast cancer, Colorectal cancer
# 915                    Breast cancer, Colorectal cancer
# 1507  Advanced breast cancer, Bladder cancer, Colore...
# 1760                                      Breast cancer
# 1812                                      Breast cancer
# 1814                                      Breast cancer
# 3880           Advanced breast cancer, Brain metastases
#
#                                           Organisations  \
# 1     Cascadian Therapeutics, Cascadian Therapeutics...
# 10    Cascadian Therapeutics, Cascadian Therapeutics...
# 16                   Seattle Genetics, Seattle Genetics
# 478                  Seattle Genetics, Seattle Genetics
# 481   Cascadian Therapeutics, Cascadian Therapeutics...
# 489                  Seattle Genetics, Seattle Genetics
# 570                  Seattle Genetics, Seattle Genetics
# 915   Cascadian Therapeutics, Cascadian Therapeutics...
# 1507                   Array BioPharma, Array BioPharma
# 1760     Cascadian Therapeutics, Cascadian Therapeutics
# 1812  Cascadian Therapeutics, Cascadian Therapeutics...
# 1814           Cascadian Therapeutics, Seattle Genetics
# 3880     Cascadian Therapeutics, Cascadian Therapeutics
#
#                                            Trial Design  \
# 1              multicentre, open, parallel, prospective
# 10    double-blind, multicentre, parallel, prospecti...
# 16                                    open, prospective
# 478    crossover, double-blind, prospective, randomised
# 481                      multicentre, open, prospective
# 489            multicentre, open, parallel, prospective
# 570            multicentre, open, parallel, prospective
# 915                                   open, prospective
# 1507                     multicentre, open, prospective
# 1760                                        prospective
# 1812                                        prospective
# 1814                                        prospective
# 3880                                        prospective
#
#                                         Trial Endpoints      ...       \
# 1     Incidence of adverse events\ntime_frame: Up to...      ...
# 10    Progression-free survival (PFS) per RECIST 1.1...      ...
# 16    Maximum observed plasma concentration (Cmax) o...      ...
# 478   Placebo-corrected change-from-baseline in QTcF...      ...
# 481   Incidence and severity of adverse events\nsafe...      ...
# 489   Maximum observed concentration\ndescription: P...      ...
# 570   Area under the concentration-time curve (AUC) ...      ...
# 915   Area under the concentration-time curve (AUC) ...      ...
# 1507  Characterize the safety profile of the study d...      ...
# 1760                                                NaN      ...
# 1812                                                NaN      ...
# 1814                                                NaN      ...
# 3880                                                NaN      ...
#
#              Trial End date                  Trial Status  \
# 1     01 Jul 2019 (planned)  Active, no longer recruiting
# 10    01 Jul 2021 (planned)                    Recruiting
# 16    01 Mar 2019 (planned)                    Recruiting
# 478   01 Mar 2019 (planned)                    Recruiting
# 481   01 Jul 2019 (planned)  Active, no longer recruiting
# 489   01 May 2019 (planned)                    Recruiting
# 570    28 Dec 2018 (actual)                     Completed
# 915    30 Jan 2018 (actual)                     Completed
# 1507   01 Mar 2013 (actual)                     Completed
# 1760              (planned)                     Suspended
# 1812              (planned)                      Planning
# 1814              (planned)                      Planning
# 3880              (planned)                      Planning
#
#                                           Trial History  \
# 1     2019-03-06|Other trial event|Last checked agai...
# 10    2019-03-06|Other trial event|Last checked agai...
# 16    2019-03-06|Other trial event|Last checked agai...
# 478   2019-02-03|Other trial event|Last checked agai...
# 481   2019-02-01|Other trial event|Last checked agai...
# 489   2019-02-01|Other trial event|Last checked agai...
# 570   2019-01-22|Other trial event|Last checked agai...
# 915        2018-12-05|New trial record|New trial record
# 1507  2018-08-31|Biomarker Update|Biomarkers informa...
# 1760  2018-04-05|Other trial event|Last checked agai...
# 1812  2018-03-09|Other trial event|According to a Se...
# 1814  2018-03-09|Other trial event|According to a Se...
# 3880       2013-08-09|New trial record|New trial record
#
#                                        Diseases treated Biomarkers-Inclusion  \
# 1     Advanced breast cancer|treatment|second-line o...                 HER2
# 10    Advanced breast cancer|treatment|second-line o...                 HER2
# 16    Breast cancer|treatment|; Colorectal cancer|tr...                  NaN
# 478   Breast cancer|treatment|; Colorectal cancer|tr...                  NaN
# 481   Advanced breast cancer|treatment|stage IV; Mal...                 HER2
# 489   Breast cancer|treatment|; Colorectal cancer|tr...                  NaN
# 570   Breast cancer|treatment|; Colorectal cancer|tr...                  NaN
# 915   Breast cancer|treatment|; Colorectal cancer|tr...                  NaN
# 1507  Advanced breast cancer|treatment|second-line o...                 HER2
# 1760  Breast cancer|treatment|second-line or greater...                  NaN
# 1812                   Breast cancer|treatment|stage IV                  NaN
# 1814                           Breast cancer|treatment|                  NaN
# 3880  Advanced breast cancer|treatment|; Brain metas...                  NaN
#
#      Biomarkers-Exclusion  Biomarkers-Outcome Measure Biomarkers-Safety  \
# 1                    HER2                         NaN               NaN
# 10                   HER2                         NaN               NaN
# 16                    NaN                         NaN               NaN
# 478                   NaN                         NaN               NaN
# 481                  HER2                         NaN               NaN
# 489                   NaN                         NaN               NaN
# 570                   NaN                         NaN               NaN
# 915                   NaN                         NaN               NaN
# 1507                  NaN                        HER2               NaN
# 1760                  NaN                         NaN               NaN
# 1812                  NaN                         NaN               NaN
# 1814                  NaN                         NaN               NaN
# 3880                  NaN                         NaN               NaN
#
#       Biomarkers-not specified Primary Drugs
# 1                          NaN     Tucatinib
# 10                         NaN     Tucatinib
# 16                         NaN     Tucatinib
# 478                        NaN     Tucatinib
# 481                        NaN     Tucatinib
# 489                        NaN     Tucatinib
# 570                        NaN     Tucatinib
# 915                        NaN     Tucatinib
# 1507                       NaN     Tucatinib
# 1760                       NaN     Tucatinib
# 1812                       NaN     Tucatinib
# 1814                       NaN     Tucatinib
# 3880                       NaN     Tucatinib
#
# [13 rows x 41 columns]

# %%
def trial_history_to_table(th):
    rows = str.split(th, ';')
    #columns_trial_1 = [str.split(i, '|') for i in rows_trial_1]
    table = [str.split(row, '|') for row in rows]
    return pd.DataFrame(table,columns=['Date','Status','Notes'])

trial_history_to_table(phase_three['Trial History'].values[0])
# Out:
#           Date                      Status  \
# 0   2019-03-06           Other trial event
# 1   2019-01-25           Other trial event
# 2   2018-12-26           Other trial event
# 3   2018-12-19  Status change - recruiting
# 4   2018-11-06            New trial record
#
#                                                Notes
# 0    Last checked against ClinicalTrials.gov record.
# 1  Last checked against the European Clinical Tri...
# 2  New source identified and integrated (European...
# 3  Status changed from not yet recruiting to recr...
# 4                                   New trial record
